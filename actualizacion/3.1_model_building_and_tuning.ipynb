# %% [markdown]
# # **Selección de Algoritmos**
# Comenzaremos con modelos base simples y progresaremos hacia algoritmos de ensamble más complejos para establecer un benchmark de rendimiento.
# # **Entrenamiento Sistemático**
# Crearemos un framework reutilizable para entrenar cada modelo, garantizando que todos sean evaluados bajo las mismas condiciones.
# # **Ajuste de Hiperparámetros**
# Optimizaremos el mejor modelo candidato para exprimir su máximo potencial predictivo.

# %% [markdown]
# # 1.- **Importar librerias**

# %%
# Importar librerías estándar
import sys
import os

# 2. Configurar la ruta para que Python encuentre el código en 'src'. Esto añade la carpeta raíz del proyecto al sys.path
ruta_raiz_proyecto = os.path.abspath(os.path.join(os.getcwd(), '../../'))
sys.path.append(ruta_raiz_proyecto)

# 3. Importar las funciones directamente.
from src.cargar_analisis import cargar_dataframe, crear_listas_variables
from src.pipelines import preparar_datos_para_modelado
from src.modelos import obtener_configuraciones_modelos, optimizar_y_comparar_modelos, guardar_artefactos_ml

print("Funciones importadas exitosamente desde src/")
# Out:
# Funciones importadas exitosamente desde src/

# %% [markdown]
# # **2.- Importar datos**

# %%
# Ruta de la base de datos
path_data = '../../data/obesity_estimation_model.csv'

# Ejecutar función para cargar datos
df = cargar_dataframe(path_data)

# Ejecutar la función para generar listas con las variables numericas, categoricas y objetivo
variables_numericas, variables_categoricas, variable_objetivo = crear_listas_variables(to_lower = 1, exclude_mixed = 1)
# Out:
# Archivo CSV cargado exitosamente desde: ../../data/obesity_estimation_model.csv

# %% [markdown]
# # **3. Preprocesamiento con Pipelines**

# %%
X_train, X_test, y_train, y_test, preprocesador = preparar_datos_para_modelado(df, variable_objetivo, 0.2, 1)
# Out:
# Iniciando la preparación de datos para el modelado...
# Datos divididos: 1258 para entrenamiento, 315 para prueba.
#
# Preprocesador creado y ajustado a los datos de entrenamiento exitosamente.

# %% [markdown]
# # **4.- Construcción y Ajuste y Evaluación de Modelos**

# %%
# Ejecutar la función para obtener los modelos a evaluar
configuracion_modelos = obtener_configuraciones_modelos()

print(f"Se cargaron {len(configuracion_modelos)} configuraciones de modelos.")
print("\nEjemplo: Parámetros de Regresión Logistica:")
print(configuracion_modelos[0]['parametros'])
# Out:
# Se cargaron 7 configuraciones de modelos.
#
# Ejemplo: Parámetros de Regresión Logistica:
# {'clasificador__penalty': ['l1', 'l2'], 'clasificador__solver': ['liblinear', 'saga', 'lbfgs'], 'clasificador__C': [0.01, 0.1, 1.0, 3.0, 10.0]}

# %%
# Ejecutar el proceso de optimización y comparación
df_resultados_opt, pipelines_optimizados = optimizar_y_comparar_modelos(
    configuracion_modelos,
    preprocesador,
    X_train, y_train, X_test, y_test
)
# Out:
# --- Optimizando: regresion_logistica ---
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# 2025/10/31 20:52:00 INFO mlflow.models.model: Found the following environment variables used during model inference: [DATABRICKS_HOST, DATABRICKS_TOKEN]. Please check if you need to set them when deploying the model. To disable this message, set environment variable `MLFLOW_RECORD_ENV_VARS_IN_MODEL_LOGGING` to `false`.
# Run registrada en MLflow para: regresion_logistica
# F1 Test: 0.9302
# Mejores parámetros: {'clasificador__C': 3.0, 'clasificador__penalty': 'l1', 'clasificador__solver': 'saga'}
# 🏃 View run regresion_logistica at: https://dbc-cb01d0d2-09c5.cloud.databricks.com/ml/experiments/3057975320962438/runs/15d64afd006540759697b9f4ebeac4f3
# 🧪 View experiment at: https://dbc-cb01d0d2-09c5.cloud.databricks.com/ml/experiments/3057975320962438
# --- Optimizando: decision_tree ---
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# Run registrada en MLflow para: decision_tree
# F1 Test: 0.9526
# Mejores parámetros: {'clasificador__criterion': 'gini', 'clasificador__max_depth': 10, 'clasificador__max_leaf_nodes': 15, 'clasificador__min_samples_leaf': 5, 'clasificador__min_samples_split': 2}
# 🏃 View run decision_tree at: https://dbc-cb01d0d2-09c5.cloud.databricks.com/ml/experiments/3057975320962438/runs/e77b8314ff3943689717a9e82938fcb0
# 🧪 View experiment at: https://dbc-cb01d0d2-09c5.cloud.databricks.com/ml/experiments/3057975320962438
# --- Optimizando: random_forest ---
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# Run registrada en MLflow para: random_forest
# F1 Test: 0.9809
# Mejores parámetros: {'clasificador__criterion': 'entropy', 'clasificador__max_depth': 15, 'clasificador__min_samples_leaf': 1, 'clasificador__min_samples_split': 2, 'clasificador__n_estimators': 100}
# 🏃 View run random_forest at: https://dbc-cb01d0d2-09c5.cloud.databricks.com/ml/experiments/3057975320962438/runs/2b95e8e09ed440be82d9c6d0e660f3a4
# 🧪 View experiment at: https://dbc-cb01d0d2-09c5.cloud.databricks.com/ml/experiments/3057975320962438
# --- Optimizando: xgboost ---
# Fitting 5 folds for each of 576 candidates, totalling 2880 fits
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# Run registrada en MLflow para: xgboost
# F1 Test: 0.9715
# Mejores parámetros: {'clasificador__colsample_bytree': 0.7, 'clasificador__learning_rate': 0.1, 'clasificador__max_depth': 7, 'clasificador__n_estimators': 100, 'clasificador__subsample': 0.8}
# 🏃 View run xgboost at: https://dbc-cb01d0d2-09c5.cloud.databricks.com/ml/experiments/3057975320962438/runs/3d300a296e3540be9bdff0c411acc9cd
# 🧪 View experiment at: https://dbc-cb01d0d2-09c5.cloud.databricks.com/ml/experiments/3057975320962438
# --- Optimizando: knn ---
# Fitting 5 folds for each of 42 candidates, totalling 210 fits
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# Run registrada en MLflow para: knn
# F1 Test: 0.9026
# Mejores parámetros: {'clasificador__metric': 'manhattan', 'clasificador__n_neighbors': 2, 'clasificador__weights': 'distance'}
# 🏃 View run knn at: https://dbc-cb01d0d2-09c5.cloud.databricks.com/ml/experiments/3057975320962438/runs/e09cd6481fcd4851b3c8eeea331ed137
# 🧪 View experiment at: https://dbc-cb01d0d2-09c5.cloud.databricks.com/ml/experiments/3057975320962438
# --- Optimizando: mlp ---
# Fitting 5 folds for each of 240 candidates, totalling 1200 fits
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# Run registrada en MLflow para: mlp
# F1 Test: 0.9433
# Mejores parámetros: {'clasificador__activation': 'relu', 'clasificador__alpha': 0.01, 'clasificador__hidden_layer_sizes': (100, 100), 'clasificador__learning_rate': 'constant', 'clasificador__solver': 'adam'}
# 🏃 View run mlp at: https://dbc-cb01d0d2-09c5.cloud.databricks.com/ml/experiments/3057975320962438/runs/f4545f1b334349bb95cc847787050693
# 🧪 View experiment at: https://dbc-cb01d0d2-09c5.cloud.databricks.com/ml/experiments/3057975320962438
# --- Optimizando: svm ---
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# Run registrada en MLflow para: svm
# F1 Test: 0.9525
# Mejores parámetros: {'clasificador__C': 2.0, 'clasificador__gamma': 0.0001, 'clasificador__kernel': 'linear'}
# 🏃 View run svm at: https://dbc-cb01d0d2-09c5.cloud.databricks.com/ml/experiments/3057975320962438/runs/e7b35dc511834e2cabe919c228285452
# 🧪 View experiment at: https://dbc-cb01d0d2-09c5.cloud.databricks.com/ml/experiments/3057975320962438
#                 Modelo  F1-Score (Train)  Accuracy (Train)  F1-Score (Test)  \
# 2        random_forest          1.000000          1.000000         0.980913
# 3              xgboost          1.000000          1.000000         0.971501
# 1        decision_tree          0.969916          0.969793         0.952610
# 6                  svm          0.965596          0.965819         0.952537
# 5                  mlp          0.962639          0.962639         0.943291
# 0  regresion_logistica          0.951515          0.951510         0.930169
# 4                  knn          1.000000          1.000000         0.902616
#
#    Accuracy (Test)                                 Mejores Parámetros
# 2         0.980952  {'clasificador__criterion': 'entropy', 'clasif...
# 3         0.971429  {'clasificador__colsample_bytree': 0.7, 'clasi...
# 1         0.952381  {'clasificador__criterion': 'gini', 'clasifica...
# 6         0.952381  {'clasificador__C': 2.0, 'clasificador__gamma'...
# 5         0.942857  {'clasificador__activation': 'relu', 'clasific...
# 0         0.930159  {'clasificador__C': 3.0, 'clasificador__penalt...
# 4         0.904762  {'clasificador__metric': 'manhattan', 'clasifi...

# %%
# Llamar a la función para guardar los artefactos
# Usamos '../artefactos/' como ruta, asumiendo la estructura de carpetas
guardar_artefactos_ml(
    df_resultados=df_resultados_opt,
    pipelines=pipelines_optimizados,
    base_path='../../artefactos/' # Se recomienda crear una carpeta separada para modelos
)
